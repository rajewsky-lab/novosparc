# %%
batch = 1
geometry = pd.read_csv('geometry_%d.txt' % batch, sep='\t')

# %%
alt.Chart(geometry).mark_circle().encode(x='xcoord:Q', y='ycoord:Q')
# Out:
# alt.Chart(...)

# %%
geometry
# Out:
#                            xcoord\tycoord
# 0    -891.313702323154\t-1464.55002409986
# 1    -609.526667604209\t-1457.75189222418
# 2    -416.254155651147\t-1451.43819021161
# 3    -283.819861812302\t-1470.76883038287
# 4    -83.9901215498551\t-1472.08305733125
# ..                                    ...
# 640    -1404.28033323698\t1670.8730548677
# 641   -1147.34641445567\t1675.45068217655
# 642    1164.40117053965\t1671.84459559011
# 643     31.242860864457\t1676.21477879776
# 644     1215.82442006411\t1676.3068806709
#
# [645 rows x 1 columns]
